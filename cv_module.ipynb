# %%
# !pip install easynmt --user
# !pip install wordcloud --user
# !pip install gensim --user
# !pip install langdetect --user
# !pip install sacremoses --user
# Out:
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: easynmt in /home/moad/.local/lib/python3.10/site-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from easynmt) (4.66.1)
# Requirement already satisfied: transformers<5,>=4.4 in /home/moad/.local/lib/python3.10/site-packages (from easynmt) (4.36.0)
# Requirement already satisfied: torch>=1.6.0 in /home/moad/.local/lib/python3.10/site-packages (from easynmt) (2.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from easynmt) (1.26.2)
# Requirement already satisfied: nltk in /home/moad/.local/lib/python3.10/site-packages (from easynmt) (3.8.1)
# Requirement already satisfied: sentencepiece in /home/moad/.local/lib/python3.10/site-packages (from easynmt) (0.1.99)
# Requirement already satisfied: fasttext in /home/moad/.local/lib/python3.10/site-packages/fasttext-0.9.2-py3.10-linux-x86_64.egg (from easynmt) (0.9.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from easynmt) (4.23.4)
# Requirement already satisfied: filelock in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (4.7.1)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.6.0->easynmt) (1.9)
# Requirement already satisfied: networkx in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (3.1.2)
# Requirement already satisfied: fsspec in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (2023.12.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/moad/.local/lib/python3.10/site-packages (from torch>=1.6.0->easynmt) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/moad/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->easynmt) (12.3.101)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/moad/.local/lib/python3.10/site-packages (from transformers<5,>=4.4->easynmt) (0.19.4)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers<5,>=4.4->easynmt) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers<5,>=4.4->easynmt) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/lib/python3/dist-packages (from transformers<5,>=4.4->easynmt) (2021.11.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.4->easynmt) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/moad/.local/lib/python3.10/site-packages (from transformers<5,>=4.4->easynmt) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /home/moad/.local/lib/python3.10/site-packages (from transformers<5,>=4.4->easynmt) (0.4.1)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext->easynmt) (2.11.1)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext->easynmt) (69.0.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk->easynmt) (8.0.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->easynmt) (1.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->easynmt) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.4->easynmt) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/moad/.local/lib/python3.10/site-packages (from requests->transformers<5,>=4.4->easynmt) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers<5,>=4.4->easynmt) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2020.6.20)
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from wordcloud) (3.5.1)
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: gensim in /home/moad/.local/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/lib/python3/dist-packages (from gensim) (1.8.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/moad/.local/lib/python3.10/site-packages (from gensim) (6.4.0)
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: langdetect in /home/moad/.local/lib/python3.10/site-packages (1.0.9)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from langdetect) (1.16.0)
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: regex in /usr/lib/python3/dist-packages (from sacremoses) (2021.11.10)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from sacremoses) (8.0.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.66.1)
# WARNING: Ignoring invalid distribution -etuptools (/usr/local/lib/python3.10/dist-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import gensim
import re
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.metrics import classification_report, confusion_matrix

# %%
df_cv = pd.read_csv("Resume/Resume.csv")

# %%
df_cv.head()
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
df_cv.isna().sum()
# Out:
# ID             0
# Resume_str     0
# Resume_html    0
# Category       0
# dtype: int64

# %%
df_cv.drop(columns = ['ID', 'Resume_html'], inplace = True)
df_cv
# Out:
#                                              Resume_str  Category
# 0              HR ADMINISTRATOR/MARKETING ASSOCIATE\...        HR
# 1              HR SPECIALIST, US HR OPERATIONS      ...        HR
# 2              HR DIRECTOR       Summary      Over 2...        HR
# 3              HR SPECIALIST       Summary    Dedica...        HR
# 4              HR MANAGER         Skill Highlights  ...        HR
# ...                                                 ...       ...
# 2479           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...  AVIATION
# 2480           GOVERNMENT RELATIONS, COMMUNICATIONS ...  AVIATION
# 2481           GEEK SQUAD AGENT         Professional...  AVIATION
# 2482           PROGRAM DIRECTOR / OFFICE MANAGER    ...  AVIATION
# 2483           STOREKEEPER II       Professional Sum...  AVIATION
#
# [2484 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/moad/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
STEMMER = nltk.stem.porter.PorterStemmer()
stop_words = set(nltk.corpus.stopwords.words('english'))

# %%
def preprocess(txt):
    # Convert to lowercase
    txt = txt.lower()
    # Remove non-alphabetic characters
    txt = re.sub('[^a-zA-Z]', ' ', txt)
    # Tokenize words
    tokens = nltk.tokenize.word_tokenize(txt)
    # Remove stopwords and apply stemming
    tokens = [STEMMER.stem(w) for w in tokens if w not in stop_words]
    
    return ' '.join(tokens)

# %%
df_cv['Resume'] = df_cv['Resume_str'].apply(lambda w: preprocess(w))
# drop original text column
df_cv.pop('Resume_str')
df_cv
# Out:
#       Category                                             Resume
# 0           HR  hr administr market associ hr administr summar...
# 1           HR  hr specialist us hr oper summari versatil medi...
# 2           HR  hr director summari year experi recruit plu ye...
# 3           HR  hr specialist summari dedic driven dynam year ...
# 4           HR  hr manag skill highlight hr skill hr depart st...
# ...        ...                                                ...
# 2479  AVIATION  rank sgt e non commiss offic charg brigad mail...
# 2480  AVIATION  govern relat commun organiz develop director p...
# 2481  AVIATION  geek squad agent profession profil support spe...
# 2482  AVIATION  program director offic manag summari highli pe...
# 2483  AVIATION  storekeep ii profession summari purpos documen...
#
# [2484 rows x 2 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df_cv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  2484 non-null   object
#  1   Resume    2484 non-null   object
# dtypes: object(2)
# memory usage: 38.9+ KB

# %%
df_cv['Category'].value_counts()
# Out:
# Category
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# FINANCE                   118
# ADVOCATE                  118
# ACCOUNTANT                118
# ENGINEERING               118
# CHEF                      118
# AVIATION                  117
# FITNESS                   117
# SALES                     116
# BANKING                   115
# HEALTHCARE                115
# CONSULTANT                115
# CONSTRUCTION              112
# PUBLIC-RELATIONS          111
# HR                        110
# DESIGNER                  107
# ARTS                      103
# TEACHER                   102
# APPAREL                    97
# DIGITAL-MEDIA              96
# AGRICULTURE                63
# AUTOMOBILE                 36
# BPO                        22
# Name: count, dtype: int64

# %%
df_cv['Category'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.show()

# %%
from matplotlib.gridspec import GridSpec
count=df_cv['Category'].value_counts()
label=df_cv['Category'].value_counts().keys()

plt.figure(1, figsize=(25,25))
grid=GridSpec(2,2)

cmap=plt.get_cmap('coolwarm')

color=[cmap(i) for i in np.linspace(0, 1, 5)]
plt.subplot(grid[0,1], aspect=1, title='Distribution')

pie=plt.pie(count, labels=label, autopct='%1.2f%%')
plt.show()

# %%
# create list of all categories
categories = np.sort(df_cv['Category'].unique())
categories
# Out:
# array(['ACCOUNTANT', 'ADVOCATE', 'AGRICULTURE', 'APPAREL', 'ARTS',
#        'AUTOMOBILE', 'AVIATION', 'BANKING', 'BPO', 'BUSINESS-DEVELOPMENT',
#        'CHEF', 'CONSTRUCTION', 'CONSULTANT', 'DESIGNER', 'DIGITAL-MEDIA',
#        'ENGINEERING', 'FINANCE', 'FITNESS', 'HEALTHCARE', 'HR',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'SALES', 'TEACHER'],
#       dtype=object)

# %%
# create new df for corpus and category
df_categories = [df_cv[df_cv['Category'] == category].loc[:, ['Resume', 'Category']] for category in categories]
df_categories[10]
# Out:
#                                                  Resume Category
# 1357  chef career focu nurs student recent obtain cn...     CHEF
# 1358  chef summari custom orient fast food worker de...     CHEF
# 1359  chef career overview dedic custom servic repre...     CHEF
# 1360  chef summari experienc cater chef skill prepar...     CHEF
# 1361  rm roxann mejia summari motiv chef compet keep...     CHEF
# ...                                                 ...      ...
# 1470  owner chef summari chef year critic acclaim wo...     CHEF
# 1471  kindergarten teacher profession summari energe...     CHEF
# 1472  substitut para profession summari profession m...     CHEF
# 1473  execut chef partner summari proven abil fine d...     CHEF
# 1474  line chef expedit summari chef year experi coo...     CHEF
#
# [118 rows x 2 columns]

# %%
def wordfreq(df):
    count = df['Resume'].str.split(expand=True).stack().value_counts().reset_index()
    count.columns = ['Word', 'Frequency']

    return count.head(10)

# %%
fig = plt.figure(figsize=(32, 64))

for i, category in enumerate(np.sort(df_cv['Category'].unique())):
    wf = wordfreq(df_categories[i])

    fig.add_subplot(12, 2, i + 1).set_title(category)
    plt.bar(wf['Word'], wf['Frequency'])
    plt.ylim(0, 3500)

plt.show()
plt.close()

# %%
## data cleaning  
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/moad/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
#function which stop words and the words less than 2 characters
def remove_stop_words (text):
  result = []
  for token in gensim.utils.simple_preprocess(text):
    if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
      result.append(token)

  return result

# %%
df_cv['clean'] = df_cv['Resume'].apply(remove_stop_words).astype(str)

# %%
df_cv['clean'][3]
# Out:
# "['specialist', 'summari', 'dedic', 'driven', 'dynam', 'year', 'custom', 'servic', 'expertis', 'motiv', 'maintain', 'custom', 'satisfact', 'contribut', 'compani', 'success', 'emphasi', 'personnel', 'process', 'manag', 'solid', 'team', 'player', 'proven', 'abil', 'establish', 'rapport', 'client', 'skill', 'type', 'touch', 'microsoft', 'program', 'word', 'excel', 'access', 'outlook', 'powerpoint', 'personnel', 'manag', 'telephon', 'inquiri', 'specialist', 'excel', 'custom', 'servic', 'skill', 'qualiti', 'custom', 'satisfact', 'primari', 'focu', 'inbound', 'outbound', 'contact', 'center', 'experi', 'excel', 'oral', 'written', 'present', 'season', 'conflict', 'resolut', 'experi', 'specialist', 'compani', 'citi', 'state', 'accentur', 'peoplelin', 'email', 'manag', 'team', 'receiv', 'inbound', 'email', 'client', 'initi', 'point', 'contact', 'answer', 'question', 'relat', 'polici', 'practic', 'resolv', 'issu', 'help', 'client', 'answer', 'inquiri', 'resolv', 'issu', 'rout', 'email', 'casework', 'resolut', 'record', 'track', 'client', 'issu', 'case', 'manag', 'tool', 'initi', 'resolut', 'maintain', 'record', 'custom', 'interact', 'transact', 'document', 'inquiri', 'complaint', 'comment', 'action', 'taken', 'custom', 'servic', 'repres', 'compani', 'citi', 'state', 'maintain', 'record', 'custom', 'interact', 'transact', 'document', 'inquiri', 'complaint', 'comment', 'action', 'taken', 'develop', 'implement', 'file', 'deliveri', 'method', 'fmla', 'short', 'term', 'disabl', 'document', 'respect', 'global', 'clientel', 'facilit', 'commun', 'absenc', 'manag', 'team', 'client', 'intern', 'department', 'team', 'organ', 'maintain', 'payrol', 'peopl', 'servic', 'databas', 'manag', 'commun', 'client', 'intern', 'extern', 'department', 'team', 'mitig', 'risk', 'resolut', 'regard', 'polici', 'transact', 'queri', 'centr', 'shift', 'supervisor', 'compani', 'citi', 'state', 'answer', 'dispatch', 'medic', 'profession', 'client', 'antonio', 'surround', 'area', 'provid', 'monitor', 'ensur', 'staff', 'adher', 'qualiti', 'control', 'maintain', 'book', 'variou', 'medic', 'staff', 'ensur', 'correct', 'staff', 'contact', 'hour', 'weekend', 'educ', 'train', 'certif', 'complet', 'busi', 'administr', 'texa', 'extens', 'servic', 'citi', 'state', 'skill', 'touch', 'type', 'file', 'access', 'microsoft', 'excel', 'microsoft', 'outlook', 'microsoft', 'powerpoint', 'microsoft', 'word']"

# %%
df_cv
# Out:
#       Category                                             Resume  \
# 0           HR  hr administr market associ hr administr summar...
# 1           HR  hr specialist us hr oper summari versatil medi...
# 2           HR  hr director summari year experi recruit plu ye...
# 3           HR  hr specialist summari dedic driven dynam year ...
# 4           HR  hr manag skill highlight hr skill hr depart st...
# ...        ...                                                ...
# 2479  AVIATION  rank sgt e non commiss offic charg brigad mail...
# 2480  AVIATION  govern relat commun organiz develop director p...
# 2481  AVIATION  geek squad agent profession profil support spe...
# 2482  AVIATION  program director offic manag summari highli pe...
# 2483  AVIATION  storekeep ii profession summari purpos documen...
#
#                                                   clean
# 0     ['administr', 'market', 'associ', 'administr',...
# 1     ['specialist', 'oper', 'summari', 'versatil', ...
# 2     ['director', 'summari', 'year', 'experi', 'rec...
# 3     ['specialist', 'summari', 'dedic', 'driven', '...
# 4     ['manag', 'skill', 'highlight', 'skill', 'depa...
# ...                                                 ...
# 2479  ['rank', 'commiss', 'offic', 'charg', 'brigad'...
# 2480  ['govern', 'relat', 'commun', 'organiz', 'deve...
# 2481  ['geek', 'squad', 'agent', 'profession', 'prof...
# 2482  ['program', 'director', 'offic', 'manag', 'sum...
# 2483  ['storekeep', 'profession', 'summari', 'purpos...
#
# [2484 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df_cv['clean'], df_cv['Category'], test_size = 0.2)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# vectorize text data
vectorizer = CountVectorizer()
conuntvectorizer_train = vectorizer.fit_transform(X_train).astype(float)
conuntvectorizer_test = vectorizer.transform(X_test).astype(float)

# %%
## model building
# using grid search for find optimal values for RF classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

RFC = RandomForestClassifier(random_state=42)

param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['sqrt', 'log2', 1, 2, 3],  
    'max_depth' : [4, 5, 6, 7, 8],
    'criterion' :['gini', 'entropy']
}


grid = GridSearchCV(estimator=RFC, param_grid=param_grid, cv= 5, scoring='accuracy', return_train_score=False, verbose=1)
grid_search = grid.fit(conuntvectorizer_train, Y_train)

print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'n_estimators': 500}

# %%
from sklearn.ensemble import RandomForestClassifier

RF_Model = RandomForestClassifier(random_state=42, max_features='sqrt', n_estimators=500, max_depth=8, criterion='gini')
RF_Model.fit(conuntvectorizer_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=500, random_state=42)

# %%
prediction=RF_Model.predict(conuntvectorizer_test)
prediction
# Out:
# array(['ACCOUNTANT', 'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS',
#        'APPAREL', 'FINANCE', 'ACCOUNTANT', 'ENGINEERING', 'CONSTRUCTION',
#        'AVIATION', 'CHEF', 'FITNESS', 'CHEF', 'FITNESS', 'AVIATION',
#        'ADVOCATE', 'BUSINESS-DEVELOPMENT', 'CHEF', 'CONSTRUCTION',
#        'FITNESS', 'SALES', 'CHEF', 'CHEF', 'BUSINESS-DEVELOPMENT',
#        'DESIGNER', 'DESIGNER', 'DESIGNER', 'BANKING', 'SALES', 'CHEF',
#        'CHEF', 'AVIATION', 'ACCOUNTANT', 'TEACHER', 'ADVOCATE',
#        'ENGINEERING', 'ENGINEERING', 'HR', 'DESIGNER', 'CONSTRUCTION',
#        'HR', 'FINANCE', 'FITNESS', 'AVIATION', 'TEACHER', 'TEACHER',
#        'SALES', 'ACCOUNTANT', 'AVIATION', 'INFORMATION-TECHNOLOGY', 'HR',
#        'SALES', 'CONSTRUCTION', 'CONSTRUCTION', 'ACCOUNTANT', 'HR',
#        'BANKING', 'FINANCE', 'DESIGNER', 'APPAREL', 'FINANCE',
#        'BUSINESS-DEVELOPMENT', 'HR', 'AVIATION', 'BANKING', 'ACCOUNTANT',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'SALES',
#        'HEALTHCARE', 'ENGINEERING', 'CHEF', 'APPAREL', 'ADVOCATE',
#        'TEACHER', 'HR', 'APPAREL', 'PUBLIC-RELATIONS', 'DESIGNER',
#        'ENGINEERING', 'AVIATION', 'CHEF', 'BANKING', 'CHEF',
#        'INFORMATION-TECHNOLOGY', 'AVIATION', 'CHEF', 'PUBLIC-RELATIONS',
#        'AVIATION', 'BUSINESS-DEVELOPMENT', 'CONSTRUCTION',
#        'BUSINESS-DEVELOPMENT', 'AVIATION', 'HR', 'ADVOCATE',
#        'INFORMATION-TECHNOLOGY', 'AGRICULTURE', 'ADVOCATE',
#        'INFORMATION-TECHNOLOGY', 'CHEF', 'CHEF', 'TEACHER',
#        'DIGITAL-MEDIA', 'DESIGNER', 'CONSTRUCTION',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY',
#        'INFORMATION-TECHNOLOGY', 'BUSINESS-DEVELOPMENT', 'FITNESS',
#        'SALES', 'BANKING', 'BUSINESS-DEVELOPMENT', 'TEACHER', 'AVIATION',
#        'ENGINEERING', 'BUSINESS-DEVELOPMENT', 'ADVOCATE',
#        'BUSINESS-DEVELOPMENT', 'HR', 'HEALTHCARE', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'AVIATION', 'ENGINEERING',
#        'CHEF', 'HEALTHCARE', 'CHEF', 'TEACHER', 'INFORMATION-TECHNOLOGY',
#        'AVIATION', 'CHEF', 'ADVOCATE', 'DESIGNER', 'SALES',
#        'PUBLIC-RELATIONS', 'DESIGNER', 'ACCOUNTANT', 'DIGITAL-MEDIA',
#        'ACCOUNTANT', 'FITNESS', 'ENGINEERING', 'TEACHER',
#        'PUBLIC-RELATIONS', 'ACCOUNTANT', 'HEALTHCARE',
#        'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY',
#        'PUBLIC-RELATIONS', 'TEACHER', 'AVIATION', 'CHEF', 'CHEF', 'CHEF',
#        'BANKING', 'AVIATION', 'HR', 'CONSULTANT', 'BUSINESS-DEVELOPMENT',
#        'HR', 'CHEF', 'CONSTRUCTION', 'CONSTRUCTION',
#        'BUSINESS-DEVELOPMENT', 'DIGITAL-MEDIA', 'BANKING', 'SALES',
#        'HEALTHCARE', 'FINANCE', 'APPAREL', 'CONSTRUCTION', 'SALES',
#        'FINANCE', 'FITNESS', 'AVIATION', 'ACCOUNTANT', 'AVIATION',
#        'ACCOUNTANT', 'AVIATION', 'HR', 'PUBLIC-RELATIONS',
#        'DIGITAL-MEDIA', 'ADVOCATE', 'CONSTRUCTION', 'ENGINEERING',
#        'ENGINEERING', 'AVIATION', 'PUBLIC-RELATIONS', 'ADVOCATE',
#        'TEACHER', 'ENGINEERING', 'SALES', 'BUSINESS-DEVELOPMENT',
#        'PUBLIC-RELATIONS', 'INFORMATION-TECHNOLOGY', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'FITNESS', 'HR', 'AVIATION',
#        'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'CHEF', 'HEALTHCARE',
#        'INFORMATION-TECHNOLOGY', 'CHEF', 'BANKING', 'CHEF',
#        'INFORMATION-TECHNOLOGY', 'FITNESS', 'BUSINESS-DEVELOPMENT',
#        'HEALTHCARE', 'HEALTHCARE', 'PUBLIC-RELATIONS', 'TEACHER',
#        'TEACHER', 'BUSINESS-DEVELOPMENT', 'ACCOUNTANT', 'BANKING',
#        'ADVOCATE', 'CONSTRUCTION', 'HR', 'CHEF', 'CONSTRUCTION', 'HR',
#        'HR', 'CHEF', 'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'HEALTHCARE',
#        'PUBLIC-RELATIONS', 'CHEF', 'BUSINESS-DEVELOPMENT', 'ADVOCATE',
#        'INFORMATION-TECHNOLOGY', 'CHEF', 'DIGITAL-MEDIA', 'HEALTHCARE',
#        'FITNESS', 'BANKING', 'BANKING', 'DESIGNER', 'ENGINEERING',
#        'DESIGNER', 'BUSINESS-DEVELOPMENT', 'CHEF', 'CHEF',
#        'PUBLIC-RELATIONS', 'TEACHER', 'CONSTRUCTION', 'SALES',
#        'ACCOUNTANT', 'ENGINEERING', 'TEACHER', 'PUBLIC-RELATIONS',
#        'TEACHER', 'DESIGNER', 'ACCOUNTANT', 'AGRICULTURE',
#        'PUBLIC-RELATIONS', 'TEACHER', 'AVIATION', 'ACCOUNTANT', 'HR',
#        'HR', 'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'AVIATION',
#        'TEACHER', 'TEACHER', 'CHEF', 'DESIGNER', 'ACCOUNTANT', 'CHEF',
#        'SALES', 'FITNESS', 'ACCOUNTANT', 'INFORMATION-TECHNOLOGY',
#        'AVIATION', 'DESIGNER', 'FINANCE', 'BUSINESS-DEVELOPMENT',
#        'CONSTRUCTION', 'BUSINESS-DEVELOPMENT', 'AVIATION', 'BANKING',
#        'DESIGNER', 'HR', 'APPAREL', 'BUSINESS-DEVELOPMENT', 'HEALTHCARE',
#        'HEALTHCARE', 'HR', 'BANKING', 'CONSTRUCTION', 'ACCOUNTANT',
#        'ENGINEERING', 'INFORMATION-TECHNOLOGY', 'HEALTHCARE',
#        'PUBLIC-RELATIONS', 'CHEF', 'HEALTHCARE', 'ENGINEERING',
#        'PUBLIC-RELATIONS', 'FINANCE', 'DIGITAL-MEDIA', 'ACCOUNTANT',
#        'CHEF', 'HR', 'ENGINEERING', 'BUSINESS-DEVELOPMENT',
#        'DIGITAL-MEDIA', 'SALES', 'FINANCE', 'CHEF', 'CONSTRUCTION',
#        'BUSINESS-DEVELOPMENT', 'ENGINEERING', 'TEACHER',
#        'BUSINESS-DEVELOPMENT', 'ENGINEERING', 'INFORMATION-TECHNOLOGY',
#        'CHEF', 'BUSINESS-DEVELOPMENT', 'FITNESS', 'ENGINEERING',
#        'FINANCE', 'HR', 'PUBLIC-RELATIONS', 'ENGINEERING', 'BANKING',
#        'ACCOUNTANT', 'AVIATION', 'INFORMATION-TECHNOLOGY', 'TEACHER',
#        'BUSINESS-DEVELOPMENT', 'HR', 'CHEF', 'ACCOUNTANT',
#        'BUSINESS-DEVELOPMENT', 'ENGINEERING', 'HEALTHCARE',
#        'INFORMATION-TECHNOLOGY', 'BANKING', 'ACCOUNTANT', 'CHEF',
#        'AVIATION', 'ADVOCATE', 'FITNESS', 'INFORMATION-TECHNOLOGY',
#        'TEACHER', 'CONSTRUCTION', 'HEALTHCARE', 'ACCOUNTANT',
#        'ACCOUNTANT', 'ENGINEERING', 'ADVOCATE', 'INFORMATION-TECHNOLOGY',
#        'ACCOUNTANT', 'CONSTRUCTION', 'ENGINEERING',
#        'INFORMATION-TECHNOLOGY', 'FINANCE', 'INFORMATION-TECHNOLOGY',
#        'HR', 'PUBLIC-RELATIONS', 'ACCOUNTANT', 'FINANCE', 'ADVOCATE',
#        'FITNESS', 'DESIGNER', 'INFORMATION-TECHNOLOGY', 'TEACHER', 'CHEF',
#        'FITNESS', 'HEALTHCARE', 'INFORMATION-TECHNOLOGY', 'HR',
#        'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'ADVOCATE', 'FINANCE',
#        'BUSINESS-DEVELOPMENT', 'HEALTHCARE', 'PUBLIC-RELATIONS',
#        'FITNESS', 'INFORMATION-TECHNOLOGY', 'HEALTHCARE', 'FINANCE',
#        'ADVOCATE', 'BANKING', 'AVIATION', 'BUSINESS-DEVELOPMENT',
#        'TEACHER', 'TEACHER', 'TEACHER', 'CONSTRUCTION', 'TEACHER',
#        'CONSTRUCTION', 'PUBLIC-RELATIONS', 'HR', 'FINANCE',
#        'PUBLIC-RELATIONS', 'HEALTHCARE', 'TEACHER', 'HEALTHCARE',
#        'CONSTRUCTION', 'TEACHER', 'HEALTHCARE', 'TEACHER',
#        'BUSINESS-DEVELOPMENT', 'FITNESS', 'ENGINEERING', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'BANKING', 'FITNESS', 'PUBLIC-RELATIONS',
#        'ADVOCATE', 'ACCOUNTANT', 'FITNESS', 'AVIATION', 'AVIATION',
#        'ADVOCATE', 'CONSTRUCTION', 'ENGINEERING', 'CONSTRUCTION',
#        'ACCOUNTANT', 'DIGITAL-MEDIA', 'ENGINEERING', 'CONSTRUCTION',
#        'PUBLIC-RELATIONS', 'PUBLIC-RELATIONS', 'INFORMATION-TECHNOLOGY',
#        'ADVOCATE', 'FINANCE', 'AVIATION', 'TEACHER',
#        'BUSINESS-DEVELOPMENT', 'TEACHER', 'FITNESS', 'ACCOUNTANT',
#        'ADVOCATE', 'ADVOCATE', 'FITNESS', 'HR', 'HR', 'TEACHER', 'HR',
#        'PUBLIC-RELATIONS', 'BUSINESS-DEVELOPMENT', 'PUBLIC-RELATIONS',
#        'FITNESS', 'CHEF', 'FINANCE', 'BANKING', 'ENGINEERING', 'FITNESS',
#        'CHEF', 'INFORMATION-TECHNOLOGY', 'FINANCE', 'ACCOUNTANT', 'HR',
#        'SALES', 'AVIATION', 'ACCOUNTANT', 'CHEF', 'ENGINEERING',
#        'BANKING', 'TEACHER', 'HEALTHCARE', 'PUBLIC-RELATIONS', 'FITNESS',
#        'FINANCE', 'PUBLIC-RELATIONS', 'INFORMATION-TECHNOLOGY', 'TEACHER',
#        'CONSTRUCTION', 'ACCOUNTANT', 'HR', 'HR', 'INFORMATION-TECHNOLOGY',
#        'HEALTHCARE', 'CHEF', 'ACCOUNTANT', 'CHEF', 'BUSINESS-DEVELOPMENT',
#        'HEALTHCARE', 'HEALTHCARE', 'TEACHER', 'ACCOUNTANT', 'HR',
#        'DIGITAL-MEDIA', 'HR', 'CHEF', 'TEACHER'], dtype=object)

# %%
print("training Score: {:.2f}".format(RF_Model.score(conuntvectorizer_train, Y_train)))
print("test Score: {:.2f}".format(RF_Model.score(conuntvectorizer_test, Y_test)))
# Out:
# training Score: 0.85
# test Score: 0.56

# %%
from sklearn import metrics
print("model report: %s: \n %s\n" % (RF_Model, metrics.classification_report(Y_test, prediction)))
# Out:
# model report: RandomForestClassifier(max_depth=8, n_estimators=500, random_state=42):
#                          precision    recall  f1-score   support
#
#             ACCOUNTANT       0.51      0.79      0.62        24
#               ADVOCATE       0.90      0.68      0.78        28
#            AGRICULTURE       1.00      0.20      0.33        10
#                APPAREL       0.67      0.17      0.27        24
#                   ARTS       0.00      0.00      0.00        20
#             AUTOMOBILE       0.00      0.00      0.00         6
#               AVIATION       0.68      0.95      0.79        22
#                BANKING       0.58      0.55      0.56        20
#                    BPO       0.00      0.00      0.00         3
#   BUSINESS-DEVELOPMENT       0.41      0.65      0.50        20
#                   CHEF       0.64      0.93      0.76        30
#           CONSTRUCTION       0.70      0.83      0.76        23
#             CONSULTANT       1.00      0.04      0.08        24
#               DESIGNER       0.56      0.43      0.49        21
#          DIGITAL-MEDIA       0.89      0.36      0.52        22
#            ENGINEERING       0.75      0.81      0.78        26
#                FINANCE       0.47      0.53      0.50        17
#                FITNESS       0.38      0.43      0.40        21
#             HEALTHCARE       0.46      0.57      0.51        21
#                     HR       0.61      0.80      0.69        25
# INFORMATION-TECHNOLOGY       0.55      0.84      0.67        25
#       PUBLIC-RELATIONS       0.41      0.92      0.57        13
#                  SALES       0.43      0.16      0.24        37
#                TEACHER       0.34      0.93      0.50        15
#
#               accuracy                           0.56       497
#              macro avg       0.54      0.52      0.47       497
#           weighted avg       0.58      0.56      0.51       497
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
